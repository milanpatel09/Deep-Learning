# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose(), dtype=torch.long)
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'], dtype=torch.long)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch.long())
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298758, train error 89.90,  test loss 2.298643, test error 89.28
# Epoch   100, train loss 1.876942, train error 71.07,  test loss 1.729386, test error 68.60
# Epoch   200, train loss 1.856951, train error 70.20,  test loss 1.710581, test error 68.05
# Epoch   300, train loss 1.853297, train error 70.15,  test loss 1.702188, test error 68.70
# Epoch   400, train loss 1.850857, train error 70.00,  test loss 1.704361, test error 68.32
# Epoch   500, train loss 1.849681, train error 69.90,  test loss 1.713224, test error 68.18
# Epoch   600, train loss 1.848266, train error 70.03,  test loss 1.697345, test error 68.07
# Epoch   700, train loss 1.845518, train error 70.07,  test loss 1.706645, test error 68.05
# Epoch   800, train loss 1.845403, train error 69.12,  test loss 1.704127, test error 68.15
# Epoch   900, train loss 1.848661, train error 69.45,  test loss 1.700744, test error 68.05
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296339, train error 88.60,  test loss 2.299865, test error 88.82
# Epoch   100, train loss 1.794130, train error 65.12,  test loss 1.655344, test error 63.33
# Epoch   200, train loss 1.752659, train error 64.68,  test loss 1.626812, test error 63.40
# Epoch   300, train loss 1.725317, train error 63.30,  test loss 1.582649, test error 60.80
# Epoch   400, train loss 1.719422, train error 62.90,  test loss 1.581150, test error 60.60
# Epoch   500, train loss 1.714538, train error 61.38,  test loss 1.575778, test error 60.92
# Epoch   600, train loss 1.712200, train error 62.40,  test loss 1.583895, test error 60.67
# Epoch   700, train loss 1.706631, train error 62.10,  test loss 1.579596, test error 61.05
# Epoch   800, train loss 1.704140, train error 61.95,  test loss 1.570971, test error 60.38
# Epoch   900, train loss 1.703769, train error 61.45,  test loss 1.565751, test error 60.38
# Training model with   6 hidden variables
# Epoch     0, train loss 2.154911, train error 81.12,  test loss 2.101750, test error 80.28
# Epoch   100, train loss 1.659865, train error 58.95,  test loss 1.511363, test error 56.30
# Epoch   200, train loss 1.634365, train error 56.65,  test loss 1.482277, test error 55.95
# Epoch   300, train loss 1.625282, train error 56.90,  test loss 1.471682, test error 54.62
# Epoch   400, train loss 1.605373, train error 56.30,  test loss 1.453776, test error 53.50
# Epoch   500, train loss 1.596618, train error 55.28,  test loss 1.441060, test error 53.03
# Epoch   600, train loss 1.580621, train error 55.17,  test loss 1.410517, test error 52.35
# Epoch   700, train loss 1.578617, train error 54.45,  test loss 1.399684, test error 51.83
# Epoch   800, train loss 1.569503, train error 54.65,  test loss 1.400600, test error 52.10
# Epoch   900, train loss 1.568451, train error 54.85,  test loss 1.408810, test error 53.00
# Training model with   8 hidden variables
# Epoch     0, train loss 2.279827, train error 84.97,  test loss 2.282090, test error 85.55
# Epoch   100, train loss 1.618914, train error 56.50,  test loss 1.474600, test error 58.12
# Epoch   200, train loss 1.578703, train error 55.40,  test loss 1.446898, test error 56.00
# Epoch   300, train loss 1.564327, train error 54.78,  test loss 1.441005, test error 55.08
# Epoch   400, train loss 1.549102, train error 54.58,  test loss 1.445604, test error 55.33
# Epoch   500, train loss 1.553396, train error 54.75,  test loss 1.457811, test error 55.22
# Epoch   600, train loss 1.539183, train error 54.08,  test loss 1.451562, test error 55.47
# Epoch   700, train loss 1.541527, train error 54.40,  test loss 1.464193, test error 55.38
# Epoch   800, train loss 1.538168, train error 54.35,  test loss 1.462420, test error 56.20
# Epoch   900, train loss 1.532146, train error 53.85,  test loss 1.457073, test error 55.50
# Training model with  10 hidden variables
# Epoch     0, train loss 2.176370, train error 81.82,  test loss 2.152117, test error 81.20
# Epoch   100, train loss 1.466440, train error 49.72,  test loss 1.314822, test error 48.12
# Epoch   200, train loss 1.433363, train error 48.92,  test loss 1.299467, test error 48.20
# Epoch   300, train loss 1.413641, train error 48.38,  test loss 1.292418, test error 47.95
# Epoch   400, train loss 1.404164, train error 48.58,  test loss 1.295520, test error 47.72
# Epoch   500, train loss 1.395518, train error 47.97,  test loss 1.302058, test error 47.53
# Epoch   600, train loss 1.393025, train error 47.97,  test loss 1.309276, test error 48.08
# Epoch   700, train loss 1.390242, train error 47.00,  test loss 1.300148, test error 47.08
# Epoch   800, train loss 1.392774, train error 47.85,  test loss 1.315790, test error 47.75
# Epoch   900, train loss 1.387094, train error 48.08,  test loss 1.319995, test error 48.38
# Training model with  14 hidden variables
# Epoch     0, train loss 2.172661, train error 80.22,  test loss 2.150305, test error 80.95
# Epoch   100, train loss 1.436937, train error 49.47,  test loss 1.334072, test error 50.28
# Epoch   200, train loss 1.374797, train error 46.92,  test loss 1.361505, test error 50.22
# Epoch   300, train loss 1.328345, train error 45.35,  test loss 1.393883, test error 50.60
# Epoch   400, train loss 1.311301, train error 44.25,  test loss 1.420226, test error 50.97
# Epoch   500, train loss 1.304405, train error 44.55,  test loss 1.446593, test error 51.28
# Epoch   600, train loss 1.296206, train error 44.88,  test loss 1.465953, test error 51.78
# Epoch   700, train loss 1.292268, train error 44.80,  test loss 1.496652, test error 52.25
# Epoch   800, train loss 1.280300, train error 44.42,  test loss 1.511680, test error 52.62
# Epoch   900, train loss 1.276532, train error 44.08,  test loss 1.518158, test error 52.38
# Training model with  18 hidden variables
# Epoch     0, train loss 2.256346, train error 84.10,  test loss 2.243779, test error 82.75
# Epoch   100, train loss 1.372533, train error 47.28,  test loss 1.328397, test error 49.40
# Epoch   200, train loss 1.273985, train error 42.67,  test loss 1.308248, test error 48.12
# Epoch   300, train loss 1.206130, train error 40.62,  test loss 1.331215, test error 48.15
# Epoch   400, train loss 1.183244, train error 39.38,  test loss 1.346716, test error 48.67
# Epoch   500, train loss 1.170547, train error 38.80,  test loss 1.362353, test error 48.65
# Epoch   600, train loss 1.158711, train error 39.20,  test loss 1.374356, test error 48.83
# Epoch   700, train loss 1.147948, train error 39.00,  test loss 1.388141, test error 48.47
# Epoch   800, train loss 1.139699, train error 38.47,  test loss 1.398761, test error 48.12
# Epoch   900, train loss 1.129055, train error 38.05,  test loss 1.402010, test error 48.22
# Training model with  22 hidden variables
# Epoch     0, train loss 2.126658, train error 79.30,  test loss 2.072191, test error 77.05
# Epoch   100, train loss 1.260543, train error 42.28,  test loss 1.335575, test error 49.58
# Epoch   200, train loss 1.124760, train error 37.08,  test loss 1.400855, test error 50.17
# Epoch   300, train loss 1.072075, train error 36.12,  test loss 1.494476, test error 50.97
# Epoch   400, train loss 1.031415, train error 35.10,  test loss 1.572589, test error 52.30
# Epoch   500, train loss 1.015583, train error 34.72,  test loss 1.645042, test error 52.65
# Epoch   600, train loss 0.988845, train error 34.15,  test loss 1.718948, test error 53.38
# Epoch   700, train loss 0.976906, train error 33.97,  test loss 1.750800, test error 53.62
# Epoch   800, train loss 0.978418, train error 34.12,  test loss 1.802726, test error 53.55
# Epoch   900, train loss 0.976317, train error 33.78,  test loss 1.854146, test error 53.60
# Training model with  26 hidden variables
# Epoch     0, train loss 2.163211, train error 79.90,  test loss 2.121862, test error 78.38
# Epoch   100, train loss 1.209338, train error 40.55,  test loss 1.342847, test error 49.05
# Epoch   200, train loss 1.051858, train error 35.62,  test loss 1.443666, test error 50.80
# Epoch   300, train loss 0.960423, train error 32.47,  test loss 1.584002, test error 51.88
# Epoch   400, train loss 0.909500, train error 30.72,  test loss 1.722564, test error 52.83
# Epoch   500, train loss 0.866758, train error 29.80,  test loss 1.844520, test error 53.40
# Epoch   600, train loss 0.846385, train error 29.53,  test loss 1.973973, test error 54.22
# Epoch   700, train loss 0.829090, train error 29.22,  test loss 2.056226, test error 54.35
# Epoch   800, train loss 0.832275, train error 29.18,  test loss 2.176061, test error 55.47
# Epoch   900, train loss 0.815630, train error 28.95,  test loss 2.237263, test error 56.08
# Training model with  30 hidden variables
# Epoch     0, train loss 2.100494, train error 77.82,  test loss 2.045269, test error 77.40
# Epoch   100, train loss 1.111623, train error 36.72,  test loss 1.341048, test error 48.83
# Epoch   200, train loss 0.910719, train error 30.88,  test loss 1.506506, test error 49.85
# Epoch   300, train loss 0.834890, train error 28.43,  test loss 1.708662, test error 52.15
# Epoch   400, train loss 0.777319, train error 26.18,  test loss 1.901028, test error 52.17
# Epoch   500, train loss 0.760402, train error 25.82,  test loss 2.071533, test error 53.47
# Epoch   600, train loss 0.711525, train error 23.97,  test loss 2.172340, test error 53.80
# Epoch   700, train loss 0.697297, train error 24.53,  test loss 2.323243, test error 54.25
# Epoch   800, train loss 0.692711, train error 24.45,  test loss 2.445742, test error 54.67
# Epoch   900, train loss 0.681069, train error 23.70,  test loss 2.517902, test error 54.85
# Training model with  35 hidden variables
# Epoch     0, train loss 2.130004, train error 79.35,  test loss 2.090857, test error 78.32
# Epoch   100, train loss 0.999863, train error 32.93,  test loss 1.397533, test error 48.30
# Epoch   200, train loss 0.777295, train error 25.18,  test loss 1.715777, test error 51.20
# Epoch   300, train loss 0.680737, train error 22.97,  test loss 2.078730, test error 53.45
# Epoch   400, train loss 0.600362, train error 19.65,  test loss 2.377252, test error 54.22
# Epoch   500, train loss 0.557842, train error 19.10,  test loss 2.686496, test error 55.12
# Epoch   600, train loss 0.522397, train error 17.65,  test loss 2.992073, test error 54.42
# Epoch   700, train loss 0.511573, train error 17.03,  test loss 3.418205, test error 55.75
# Epoch   800, train loss 0.510378, train error 17.55,  test loss 3.685127, test error 56.25
# Epoch   900, train loss 0.449625, train error 15.07,  test loss 3.958403, test error 55.55
# Training model with  40 hidden variables
# Epoch     0, train loss 2.081861, train error 78.18,  test loss 2.033698, test error 76.55
# Epoch   100, train loss 0.930789, train error 30.97,  test loss 1.452396, test error 49.75
# Epoch   200, train loss 0.626926, train error 20.25,  test loss 1.903167, test error 52.75
# Epoch   300, train loss 0.505898, train error 15.78,  test loss 2.484298, test error 55.62
# Epoch   400, train loss 0.388824, train error 12.57,  test loss 3.041451, test error 55.97
# Epoch   500, train loss 0.362688, train error 12.90,  test loss 3.766155, test error 55.83
# Epoch   600, train loss 0.349921, train error 12.43,  test loss 4.420406, test error 56.42
# Epoch   700, train loss 0.294365, train error 10.03,  test loss 5.073031, test error 56.65
# Epoch   800, train loss 0.288530, train error 10.30,  test loss 5.725423, test error 57.10
# Epoch   900, train loss 0.265550, train error 10.03,  test loss 6.340205, test error 57.15
# Training model with  45 hidden variables
# Epoch     0, train loss 2.082824, train error 78.15,  test loss 2.036945, test error 77.10
# Epoch   100, train loss 0.790201, train error 25.30,  test loss 1.481426, test error 49.53
# Epoch   200, train loss 0.460306, train error 14.90,  test loss 2.283652, test error 52.78
# Epoch   300, train loss 0.292288, train error 8.45,  test loss 3.492491, test error 55.30
# Epoch   400, train loss 0.150006, train error 3.60,  test loss 4.690181, test error 56.05
# Epoch   500, train loss 0.095806, train error 2.03,  test loss 6.149638, test error 56.83
# Epoch   600, train loss 0.024628, train error 0.03,  test loss 7.406163, test error 56.75
# Epoch   700, train loss 0.014220, train error 0.00,  test loss 8.361871, test error 57.05
# Epoch   800, train loss 0.009637, train error 0.00,  test loss 9.031944, test error 57.08
# Epoch   900, train loss 0.007290, train error 0.00,  test loss 9.580520, test error 57.05
# Training model with  50 hidden variables
# Epoch     0, train loss 2.048272, train error 76.10,  test loss 1.991209, test error 75.15
# Epoch   100, train loss 0.676701, train error 20.47,  test loss 1.663727, test error 52.83
# Epoch   200, train loss 0.324210, train error 9.32,  test loss 2.736129, test error 53.30
# Epoch   300, train loss 0.144877, train error 3.70,  test loss 4.281014, test error 54.30
# Epoch   400, train loss 0.024367, train error 0.03,  test loss 5.818115, test error 55.12
# Epoch   500, train loss 0.011916, train error 0.00,  test loss 6.686875, test error 55.30
# Epoch   600, train loss 0.007945, train error 0.00,  test loss 7.277069, test error 55.53
# Epoch   700, train loss 0.005610, train error 0.00,  test loss 7.724313, test error 55.55
# Epoch   800, train loss 0.004346, train error 0.00,  test loss 8.085923, test error 55.65
# Epoch   900, train loss 0.003510, train error 0.00,  test loss 8.382441, test error 55.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.121763, train error 78.97,  test loss 2.083320, test error 77.20
# Epoch   100, train loss 0.644292, train error 19.05,  test loss 1.620039, test error 52.05
# Epoch   200, train loss 0.239542, train error 5.97,  test loss 2.991559, test error 56.25
# Epoch   300, train loss 0.046861, train error 0.03,  test loss 4.760419, test error 56.80
# Epoch   400, train loss 0.015656, train error 0.00,  test loss 5.841915, test error 56.97
# Epoch   500, train loss 0.008969, train error 0.00,  test loss 6.498548, test error 57.03
# Epoch   600, train loss 0.006002, train error 0.00,  test loss 6.955946, test error 57.03
# Epoch   700, train loss 0.004487, train error 0.00,  test loss 7.310499, test error 57.10
# Epoch   800, train loss 0.003536, train error 0.00,  test loss 7.609667, test error 57.20
# Epoch   900, train loss 0.002896, train error 0.00,  test loss 7.853402, test error 57.25
# Training model with  60 hidden variables
# Epoch     0, train loss 2.038229, train error 76.70,  test loss 1.963584, test error 75.88
# Epoch   100, train loss 0.520894, train error 14.65,  test loss 1.693508, test error 50.25
# Epoch   200, train loss 0.119596, train error 1.65,  test loss 3.261201, test error 53.05
# Epoch   300, train loss 0.019787, train error 0.00,  test loss 4.601085, test error 52.88
# Epoch   400, train loss 0.009310, train error 0.00,  test loss 5.311631, test error 52.95
# Epoch   500, train loss 0.005883, train error 0.00,  test loss 5.768546, test error 53.10
# Epoch   600, train loss 0.004200, train error 0.00,  test loss 6.099601, test error 53.20
# Epoch   700, train loss 0.003220, train error 0.00,  test loss 6.368399, test error 53.28
# Epoch   800, train loss 0.002591, train error 0.00,  test loss 6.588188, test error 53.42
# Epoch   900, train loss 0.002150, train error 0.00,  test loss 6.776099, test error 53.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.061054, train error 77.75,  test loss 2.006152, test error 75.82
# Epoch   100, train loss 0.398860, train error 10.57,  test loss 1.903064, test error 51.20
# Epoch   200, train loss 0.035129, train error 0.00,  test loss 3.521362, test error 53.65
# Epoch   300, train loss 0.011453, train error 0.00,  test loss 4.341875, test error 53.80
# Epoch   400, train loss 0.006299, train error 0.00,  test loss 4.790016, test error 53.83
# Epoch   500, train loss 0.004222, train error 0.00,  test loss 5.101143, test error 53.85
# Epoch   600, train loss 0.003110, train error 0.00,  test loss 5.341984, test error 54.10
# Epoch   700, train loss 0.002437, train error 0.00,  test loss 5.531770, test error 54.08
# Epoch   800, train loss 0.001988, train error 0.00,  test loss 5.695940, test error 54.03
# Epoch   900, train loss 0.001671, train error 0.00,  test loss 5.831563, test error 53.92
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024580, train error 74.53,  test loss 1.990464, test error 75.50
# Epoch   100, train loss 0.280931, train error 6.35,  test loss 2.110732, test error 51.97
# Epoch   200, train loss 0.023598, train error 0.00,  test loss 3.507289, test error 53.00
# Epoch   300, train loss 0.009032, train error 0.00,  test loss 4.116408, test error 53.08
# Epoch   400, train loss 0.005214, train error 0.00,  test loss 4.480283, test error 53.10
# Epoch   500, train loss 0.003570, train error 0.00,  test loss 4.732076, test error 53.00
# Epoch   600, train loss 0.002674, train error 0.00,  test loss 4.926913, test error 53.17
# Epoch   700, train loss 0.002112, train error 0.00,  test loss 5.085313, test error 53.15
# Epoch   800, train loss 0.001735, train error 0.00,  test loss 5.220529, test error 53.28
# Epoch   900, train loss 0.001465, train error 0.00,  test loss 5.335669, test error 53.25
# Training model with  90 hidden variables
# Epoch     0, train loss 1.998485, train error 73.62,  test loss 1.959147, test error 74.68
# Epoch   100, train loss 0.138526, train error 1.05,  test loss 2.280593, test error 51.42
# Epoch   200, train loss 0.014680, train error 0.00,  test loss 3.362326, test error 52.03
# Epoch   300, train loss 0.006533, train error 0.00,  test loss 3.806426, test error 52.17
# Epoch   400, train loss 0.004018, train error 0.00,  test loss 4.083945, test error 52.53
# Epoch   500, train loss 0.002828, train error 0.00,  test loss 4.280917, test error 52.35
# Epoch   600, train loss 0.002155, train error 0.00,  test loss 4.436197, test error 52.45
# Epoch   700, train loss 0.001725, train error 0.00,  test loss 4.565536, test error 52.50
# Epoch   800, train loss 0.001429, train error 0.00,  test loss 4.672019, test error 52.47
# Epoch   900, train loss 0.001213, train error 0.00,  test loss 4.764534, test error 52.45
# Training model with 100 hidden variables
# Epoch     0, train loss 2.036884, train error 76.30,  test loss 1.998056, test error 76.20
# Epoch   100, train loss 0.115007, train error 0.47,  test loss 2.185092, test error 50.95
# Epoch   200, train loss 0.013146, train error 0.00,  test loss 3.064195, test error 51.22
# Epoch   300, train loss 0.005993, train error 0.00,  test loss 3.427225, test error 51.12
# Epoch   400, train loss 0.003703, train error 0.00,  test loss 3.660210, test error 51.08
# Epoch   500, train loss 0.002622, train error 0.00,  test loss 3.827608, test error 51.15
# Epoch   600, train loss 0.002002, train error 0.00,  test loss 3.959575, test error 51.28
# Epoch   700, train loss 0.001606, train error 0.00,  test loss 4.066715, test error 51.22
# Epoch   800, train loss 0.001332, train error 0.00,  test loss 4.158609, test error 51.28
# Epoch   900, train loss 0.001134, train error 0.00,  test loss 4.235949, test error 51.28
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980159, train error 73.72,  test loss 1.895209, test error 73.38
# Epoch   100, train loss 0.050714, train error 0.00,  test loss 2.211481, test error 49.97
# Epoch   200, train loss 0.009502, train error 0.00,  test loss 2.830834, test error 50.97
# Epoch   300, train loss 0.004717, train error 0.00,  test loss 3.112689, test error 50.97
# Epoch   400, train loss 0.003023, train error 0.00,  test loss 3.296602, test error 51.00
# Epoch   500, train loss 0.002176, train error 0.00,  test loss 3.431254, test error 50.90
# Epoch   600, train loss 0.001682, train error 0.00,  test loss 3.537418, test error 50.83
# Epoch   700, train loss 0.001360, train error 0.00,  test loss 3.624790, test error 50.90
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.699682, test error 50.88
# Epoch   900, train loss 0.000971, train error 0.00,  test loss 3.764352, test error 50.80
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962487, train error 72.12,  test loss 1.905480, test error 73.50
# Epoch   100, train loss 0.034525, train error 0.00,  test loss 2.117309, test error 49.50
# Epoch   200, train loss 0.007917, train error 0.00,  test loss 2.589208, test error 49.85
# Epoch   300, train loss 0.004090, train error 0.00,  test loss 2.817545, test error 49.97
# Epoch   400, train loss 0.002658, train error 0.00,  test loss 2.965349, test error 49.85
# Epoch   500, train loss 0.001935, train error 0.00,  test loss 3.076522, test error 49.78
# Epoch   600, train loss 0.001504, train error 0.00,  test loss 3.163879, test error 49.85
# Epoch   700, train loss 0.001222, train error 0.00,  test loss 3.237061, test error 49.97
# Epoch   800, train loss 0.001023, train error 0.00,  test loss 3.299451, test error 50.03
# Epoch   900, train loss 0.000877, train error 0.00,  test loss 3.353935, test error 49.97
# Training model with 160 hidden variables
# Epoch     0, train loss 1.920612, train error 70.28,  test loss 1.858480, test error 70.93
# Epoch   100, train loss 0.028157, train error 0.00,  test loss 2.093036, test error 48.78
# Epoch   200, train loss 0.007163, train error 0.00,  test loss 2.498060, test error 48.88
# Epoch   300, train loss 0.003745, train error 0.00,  test loss 2.696832, test error 48.83
# Epoch   400, train loss 0.002462, train error 0.00,  test loss 2.828761, test error 48.80
# Epoch   500, train loss 0.001800, train error 0.00,  test loss 2.927294, test error 48.62
# Epoch   600, train loss 0.001405, train error 0.00,  test loss 3.006788, test error 48.72
# Epoch   700, train loss 0.001143, train error 0.00,  test loss 3.072018, test error 48.72
# Epoch   800, train loss 0.000959, train error 0.00,  test loss 3.128160, test error 48.75
# Epoch   900, train loss 0.000823, train error 0.00,  test loss 3.177911, test error 48.83
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928511, train error 71.03,  test loss 1.863756, test error 73.32
# Epoch   100, train loss 0.024326, train error 0.00,  test loss 2.053179, test error 48.58
# Epoch   200, train loss 0.006613, train error 0.00,  test loss 2.409684, test error 48.50
# Epoch   300, train loss 0.003537, train error 0.00,  test loss 2.588251, test error 48.33
# Epoch   400, train loss 0.002339, train error 0.00,  test loss 2.707725, test error 48.45
# Epoch   500, train loss 0.001720, train error 0.00,  test loss 2.796896, test error 48.28
# Epoch   600, train loss 0.001348, train error 0.00,  test loss 2.869140, test error 48.28
# Epoch   700, train loss 0.001100, train error 0.00,  test loss 2.928822, test error 48.25
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 2.980096, test error 48.28
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.024817, test error 48.30
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931179, train error 71.28,  test loss 1.880602, test error 73.53
# Epoch   100, train loss 0.021224, train error 0.00,  test loss 2.000738, test error 48.28
# Epoch   200, train loss 0.006008, train error 0.00,  test loss 2.321442, test error 48.05
# Epoch   300, train loss 0.003270, train error 0.00,  test loss 2.486835, test error 48.12
# Epoch   400, train loss 0.002182, train error 0.00,  test loss 2.599700, test error 48.12
# Epoch   500, train loss 0.001612, train error 0.00,  test loss 2.684924, test error 48.12
# Epoch   600, train loss 0.001266, train error 0.00,  test loss 2.753248, test error 48.33
# Epoch   700, train loss 0.001035, train error 0.00,  test loss 2.810396, test error 48.30
# Epoch   800, train loss 0.000872, train error 0.00,  test loss 2.859323, test error 48.20
# Epoch   900, train loss 0.000750, train error 0.00,  test loss 2.902530, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886481, train error 68.30,  test loss 1.814505, test error 70.57
# Epoch   100, train loss 0.017904, train error 0.00,  test loss 1.926985, test error 46.88
# Epoch   200, train loss 0.005471, train error 0.00,  test loss 2.177569, test error 46.58
# Epoch   300, train loss 0.003032, train error 0.00,  test loss 2.313362, test error 46.50
# Epoch   400, train loss 0.002044, train error 0.00,  test loss 2.405821, test error 46.72
# Epoch   500, train loss 0.001519, train error 0.00,  test loss 2.477612, test error 46.78
# Epoch   600, train loss 0.001198, train error 0.00,  test loss 2.533987, test error 46.83
# Epoch   700, train loss 0.000984, train error 0.00,  test loss 2.581369, test error 46.85
# Epoch   800, train loss 0.000830, train error 0.00,  test loss 2.622724, test error 46.85
# Epoch   900, train loss 0.000716, train error 0.00,  test loss 2.658242, test error 46.92
# Training model with 300 hidden variables
# Epoch     0, train loss 1.897841, train error 69.53,  test loss 1.818880, test error 70.95
# Epoch   100, train loss 0.014601, train error 0.00,  test loss 1.878656, test error 46.12
# Epoch   200, train loss 0.004862, train error 0.00,  test loss 2.101810, test error 46.05
# Epoch   300, train loss 0.002752, train error 0.00,  test loss 2.220484, test error 45.83
# Epoch   400, train loss 0.001874, train error 0.00,  test loss 2.305067, test error 45.85
# Epoch   500, train loss 0.001401, train error 0.00,  test loss 2.367810, test error 45.75
# Epoch   600, train loss 0.001110, train error 0.00,  test loss 2.419069, test error 45.92
# Epoch   700, train loss 0.000913, train error 0.00,  test loss 2.462209, test error 45.95
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.499498, test error 45.97
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.532266, test error 45.92
# Training model with 400 hidden variables
# Epoch     0, train loss 1.849780, train error 66.55,  test loss 1.787779, test error 70.57
# Epoch   100, train loss 0.011703, train error 0.00,  test loss 1.792584, test error 46.67
# Epoch   200, train loss 0.004173, train error 0.00,  test loss 1.969209, test error 46.58
# Epoch   300, train loss 0.002417, train error 0.00,  test loss 2.067755, test error 46.42
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.136271, test error 46.38
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.188797, test error 46.45
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.231933, test error 46.35
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.268026, test error 46.35
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.299641, test error 46.28
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.326785, test error 46.22

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
